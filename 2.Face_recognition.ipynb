# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install opencv-python

# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566173 sha256=60e19adacc468648fa309128ee807b105ecc81a6c49693bc232363bb4d4ff9b0
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import cv2
import numpy as np
import face_recognition
import os
from datetime import datetime
from google.colab.patches import cv2_imshow

# %% [markdown]
# Step 1: Load photos

# %%
imgmaryam = cv2.imread('/content/drive/MyDrive/Attendance/Maryam_Taherirani.jpg')
imgmaryam = cv2.cvtColor(imgmaryam,cv2.COLOR_BGR2RGB)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(imgmaryam)
plt.show()

# %%
imgtest = cv2.imread('/content/drive/MyDrive/Attendance/Maryamtest.jpg')
imgtest = cv2.cvtColor(imgtest,cv2.COLOR_BGR2RGB)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(imgtest)
plt.show()

# %%
imgtrinh = cv2.imread('/content/drive/MyDrive/Attendance/Trinh_Phan.jpg')
imgtrinh = cv2.cvtColor(imgtrinh,cv2.COLOR_BGR2RGB)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(imgtrinh)
plt.show()

# %%
imgtaylor = cv2.imread('/content/drive/MyDrive/Attendance/Taylor_Murray.jpg')
imgtaylor = cv2.cvtColor(imgtaylor,cv2.COLOR_BGR2RGB)
imgtaylor = cv2.resize(imgtaylor,(0,0),None,0.25,0.25)
# %matplotlib inline
import matplotlib.pyplot as plt
plt.imshow(imgtaylor)
plt.show()

# %% [markdown]
# Step 2: Find the face in our photos and enbeding code

# %%
faceLoc = face_recognition.face_locations(imgmaryam)[0]
encodeMaryam = face_recognition.face_encodings(imgmaryam)[0]
cv2.rectangle(imgmaryam,(faceLoc[3],faceLoc[0]),(faceLoc[1],faceLoc[2]),(255,0,255),2)
# Out:
# array([[[218, 208, 206],
#         [218, 208, 206],
#         [217, 207, 205],
#         ...,
#         [191, 182, 173],
#         [192, 183, 174],
#         [192, 183, 174]],
#
#        [[217, 207, 205],
#         [217, 207, 205],
#         [217, 207, 205],
#         ...,
#         [199, 190, 181],
#         [200, 191, 182],
#         [201, 192, 183]],
#
#        [[217, 207, 205],
#         [217, 207, 205],
#         [217, 207, 205],
#         ...,
#         [188, 179, 170],
#         [191, 182, 173],
#         [193, 184, 175]],
#
#        ...,
#
#        [[ 78,  71, 104],
#         [ 78,  71, 104],
#         [ 79,  72, 105],
#         ...,
#         [ 76,  67,  94],
#         [ 76,  67,  94],
#         [ 76,  67,  94]],
#
#        [[ 78,  71, 104],
#         [ 78,  71, 104],
#         [ 79,  72, 105],
#         ...,
#         [ 77,  68,  95],
#         [ 77,  68,  95],
#         [ 77,  68,  95]],
#
#        [[ 78,  71, 104],
#         [ 78,  71, 104],
#         [ 79,  72, 105],
# ...

# %%
# Test photos
faceLoctest = face_recognition.face_locations(imgtest)[0]
encodetest = face_recognition.face_encodings(imgtest)[0]
cv2.rectangle(imgtest,(faceLoctest[3],faceLoctest[0]),(faceLoctest[1],faceLoctest[2]),(255,0,255),2)
# Out:
# array([[[191, 130, 101],
#         [191, 130, 101],
#         [198, 137, 106],
#         ...,
#         [215, 158, 128],
#         [196, 139, 109],
#         [194, 137, 107]],
#
#        [[168, 113,  82],
#         [162, 107,  76],
#         [161, 106,  75],
#         ...,
#         [196, 139, 109],
#         [204, 149, 118],
#         [213, 156, 126]],
#
#        [[192, 147, 114],
#         [191, 146, 113],
#         [194, 149, 116],
#         ...,
#         [200, 145, 114],
#         [199, 146, 114],
#         [208, 153, 122]],
#
#        ...,
#
#        [[ 62,  52,  43],
#         [ 57,  47,  38],
#         [ 66,  52,  49],
#         ...,
#         [199, 210, 216],
#         [193, 204, 210],
#         [193, 204, 210]],
#
#        [[ 58,  49,  40],
#         [ 61,  51,  42],
#         [ 75,  62,  56],
#         ...,
#         [187, 198, 204],
#         [185, 196, 202],
#         [189, 200, 206]],
#
#        [[ 64,  57,  49],
#         [ 66,  57,  50],
#         [ 71,  60,  56],
# ...

# %%
# Test another photo
faceLoctest2 = face_recognition.face_locations(imgtaylor)[0]
encodetest2= face_recognition.face_encodings(imgtaylor)[0]
cv2.rectangle(imgtaylor,(faceLoctest2[3],faceLoctest2[0]),(faceLoctest2[1],faceLoctest2[2]),(255,0,255),2)
# Out:
# array([[[144, 146, 145],
#         [140, 144, 145],
#         [142, 146, 147],
#         ...,
#         [114, 110, 133],
#         [116, 112, 135],
#         [113, 109, 132]],
#
#        [[141, 143, 143],
#         [141, 145, 146],
#         [146, 150, 151],
#         ...,
#         [115, 111, 134],
#         [117, 113, 136],
#         [113, 109, 132]],
#
#        [[143, 144, 146],
#         [140, 144, 145],
#         [145, 149, 150],
#         ...,
#         [117, 113, 136],
#         [115, 111, 134],
#         [113, 109, 132]],
#
#        ...,
#
#        [[179, 163, 112],
#         [181, 165, 114],
#         [181, 165, 114],
#         ...,
#         [188, 170, 148],
#         [195, 177, 155],
#         [194, 176, 154]],
#
#        [[175, 159, 108],
#         [185, 169, 118],
#         [180, 164, 113],
#         ...,
#         [183, 165, 143],
#         [186, 168, 146],
#         [187, 169, 147]],
#
#        [[175, 159, 108],
#         [180, 164, 113],
#         [183, 167, 116],
# ...

# %%
faceLoctest = face_recognition.face_locations(imgtaylor)[0]
encodetaylor= face_recognition.face_encodings(imgtaylor)[0]
cv2.rectangle(imgtaylor,(faceLoctest[3],faceLoctest[0]),(faceLoctest[1],faceLoctest[2]),(255,0,255),2)
# Out:
# array([[[144, 146, 145],
#         [140, 144, 145],
#         [142, 146, 147],
#         ...,
#         [114, 110, 133],
#         [116, 112, 135],
#         [113, 109, 132]],
#
#        [[141, 143, 143],
#         [141, 145, 146],
#         [146, 150, 151],
#         ...,
#         [115, 111, 134],
#         [117, 113, 136],
#         [113, 109, 132]],
#
#        [[143, 144, 146],
#         [140, 144, 145],
#         [145, 149, 150],
#         ...,
#         [117, 113, 136],
#         [115, 111, 134],
#         [113, 109, 132]],
#
#        ...,
#
#        [[179, 163, 112],
#         [181, 165, 114],
#         [181, 165, 114],
#         ...,
#         [188, 170, 148],
#         [195, 177, 155],
#         [194, 176, 154]],
#
#        [[175, 159, 108],
#         [185, 169, 118],
#         [180, 164, 113],
#         ...,
#         [183, 165, 143],
#         [186, 168, 146],
#         [187, 169, 147]],
#
#        [[175, 159, 108],
#         [180, 164, 113],
#         [183, 167, 116],
# ...

# %%
plt.imshow(imgtaylor)
plt.show()

# %%
imgmaryam.shape
# Out:
# (420, 356, 3)

# %%
imgtaylor.shape
# Out:
# (772, 579, 3)

# %% [markdown]
# Step 3: Compare distance between 2 photos

# %%
faceDis = face_recognition.face_distance([encodeMaryam],encodetest)
print(faceDis)
results = face_recognition.compare_faces([encodeMaryam],encodetest)
cv2.putText(imgtest,f'{results} {round(faceDis[0],2)}',(50,50),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
# Out:
# [0.43874306]
# array([[[191, 130, 101],
#         [191, 130, 101],
#         [198, 137, 106],
#         ...,
#         [215, 158, 128],
#         [196, 139, 109],
#         [194, 137, 107]],
#
#        [[168, 113,  82],
#         [162, 107,  76],
#         [161, 106,  75],
#         ...,
#         [196, 139, 109],
#         [204, 149, 118],
#         [213, 156, 126]],
#
#        [[192, 147, 114],
#         [191, 146, 113],
#         [194, 149, 116],
#         ...,
#         [200, 145, 114],
#         [199, 146, 114],
#         [208, 153, 122]],
#
#        ...,
#
#        [[ 62,  52,  43],
#         [ 57,  47,  38],
#         [ 66,  52,  49],
#         ...,
#         [199, 210, 216],
#         [193, 204, 210],
#         [193, 204, 210]],
#
#        [[ 58,  49,  40],
#         [ 61,  51,  42],
#         [ 75,  62,  56],
#         ...,
#         [187, 198, 204],
#         [185, 196, 202],
#         [189, 200, 206]],
#
#        [[ 64,  57,  49],
#         [ 66,  57,  50],
# ...

# %%
plt.imshow(imgtest)
plt.show()

# %%
faceDis2 = face_recognition.face_distance([encodetaylor],encodetest)
print(faceDis)
results2 = face_recognition.compare_faces([encodetaylor],encodetest)
cv2.putText(imgtaylor,f'{results2} {round(faceDis2[0],2)}',(200,500),cv2.FONT_HERSHEY_COMPLEX,1,(0,0,255),2)
# Out:
# [0.77906395 0.17864939 0.71034481 0.64890757]
# array([[[144, 146, 145],
#         [140, 144, 145],
#         [142, 146, 147],
#         ...,
#         [114, 110, 133],
#         [116, 112, 135],
#         [113, 109, 132]],
#
#        [[141, 143, 143],
#         [141, 145, 146],
#         [146, 150, 151],
#         ...,
#         [115, 111, 134],
#         [117, 113, 136],
#         [113, 109, 132]],
#
#        [[143, 144, 146],
#         [140, 144, 145],
#         [145, 149, 150],
#         ...,
#         [117, 113, 136],
#         [115, 111, 134],
#         [113, 109, 132]],
#
#        ...,
#
#        [[179, 163, 112],
#         [181, 165, 114],
#         [181, 165, 114],
#         ...,
#         [188, 170, 148],
#         [195, 177, 155],
#         [194, 176, 154]],
#
#        [[175, 159, 108],
#         [185, 169, 118],
#         [180, 164, 113],
#         ...,
#         [183, 165, 143],
#         [186, 168, 146],
#         [187, 169, 147]],
#
#        [[175, 159, 108],
# ...

# %%
plt.imshow(imgtaylor)
plt.show()

# %% [markdown]
# Step 4: Take photo from camera

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
def markAttendance(name):
    with open('/content/drive/MyDrive/Attendance.csv','r+') as f:
        myDataList = f.readlines()
        nameList = []
        for line in myDataList:
            entry = line.split(',')
            nameList.append(entry[0])
        if name not in nameList:
            now = datetime.now()
            dtString = now.strftime('%H:%M:%S')
            f.writelines(f'\n{name},{dtString}')

# %%
photo = cv2.imread('/content/photo.jpg')
imgS = cv2.resize(photo,(0,0),None,0.25,0.25)
imgS = cv2.cvtColor(photo, cv2.COLOR_BGR2RGB)
facesCurFrame = face_recognition.face_locations(imgS)
encodesCurFrame = face_recognition.face_encodings(imgS,facesCurFrame)
 
for encodeFace,faceLoc in zip(encodesCurFrame,facesCurFrame):
        matches = face_recognition.compare_faces(encodeListKnown,encodeFace)
        faceDis = face_recognition.face_distance(encodeListKnown,encodeFace)
        #print(faceDis)
        matchIndex = np.argmin(faceDis)
 
        if matches[matchIndex]:
            name = classNames[matchIndex].upper()
            #print(name)
            y1,x2,y2,x1 = faceLoc
            y1, x2, y2, x1 = y1*4,x2*4,y2*4,x1*4
            cv2.rectangle(imgS,(x1,y1),(x2,y2),(0,255,0),2)
            cv2.rectangle(imgS,(x1,y2-35),(x2,y2),(0,255,0),cv2.FILLED)
            cv2.putText(imgS,name,(x1+6,y2-6),cv2.FONT_HERSHEY_COMPLEX,1,(255,255,255),2)
            markAttendance(name)

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
photo = cv2.imread('/content/photo.jpg')
imgS = cv2.resize(photo,(0,0),None,0.25,0.25)
imgS = cv2.cvtColor(photo, cv2.COLOR_BGR2RGB)
facesCurFrame = face_recognition.face_locations(imgS)
encodesCurFrame = face_recognition.face_encodings(imgS,facesCurFrame)
 
for encodeFace,faceLoc in zip(encodesCurFrame,facesCurFrame):
        matches = face_recognition.compare_faces(encodeListKnown,encodeFace)
        faceDis = face_recognition.face_distance(encodeListKnown,encodeFace)
        #print(faceDis)
        matchIndex = np.argmin(faceDis)
 
        if matches[matchIndex]:
            name = classNames[matchIndex].upper()
            #print(name)
            y1,x2,y2,x1 = faceLoc
            y1, x2, y2, x1 = y1*4,x2*4,y2*4,x1*4
            cv2.rectangle(imgS,(x1,y1),(x2,y2),(0,255,0),2)
            cv2.rectangle(imgS,(x1,y2-35),(x2,y2),(0,255,0),cv2.FILLED)
            cv2.putText(imgS,name,(x1+6,y2-6),cv2.FONT_HERSHEY_COMPLEX,1,(255,255,255),2)
            markAttendance(name)

# %%
from IPython.display import Image
try:
  filename = take_photo()
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to photo.jpg

# %%
import pandas as pd
check=pd.read_csv('/content/drive/MyDrive/Attendance.csv')
check.head()
# Out:
#                 Name      Time
# 0              TRINH  05:55:32
# 1  MARYAM_TAHERIRANI  06:18:43
# 2      TAYLOR_MURRAY  06:22:02
# 3         TRINH_PHAN  06:26:22
